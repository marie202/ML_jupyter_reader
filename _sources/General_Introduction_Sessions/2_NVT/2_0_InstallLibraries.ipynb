# %% [markdown]
# # 2. Recap Statistics
#
# ### Installation of needed libraries
#
# If the libraries have not yet been installed in the corresponding environment, this can be done with one of the following two code cells.
#
# ### ... using conda

# %%
# Installiere die notwendigen Bibliotheken mit conda
import sys
# !conda update --yes -n base -c  defaults conda
# !conda install --yes --prefix {sys.prefix} numpy matplotlib pandas seaborn matplotlib scipy
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/jupyter_book_ml
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scipy
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.7           |   py39hbda83bc_0         110 KB
#     brotli-1.0.9               |       h80987f9_8          20 KB
#     brotli-bin-1.0.9           |       h80987f9_8          18 KB
#     contourpy-1.2.0            |   py39h48ca7d4_0         239 KB
#     fonttools-4.51.0           |   py39h80987f9_0         2.4 MB
#     kiwisolver-1.4.4           |   py39h313beb8_0          61 KB
#     libbrotlicommon-1.0.9      |       h80987f9_8          70 KB
#     libbrotlidec-1.0.9         |       h80987f9_8          29 KB
#     libbrotlienc-1.0.9         |       h80987f9_8         291 KB
#     lz4-c-1.9.4                |       h313beb8_1         157 KB
#     matplotlib-3.8.4           |   py39hca03da5_0           9 KB
#     matplotlib-base-3.8.4      |   py39h46d7db6_0         6.7 MB
#     numexpr-2.8.7              |   py39hecc3335_0         124 KB
#     numpy-1.26.4               |   py39h3b2db8e_0          12 KB
#     numpy-base-1.26.4          |   py39ha9811e2_0         5.8 MB
#     openjpeg-2.4.0             |       h0ed58ac_2         307 KB
#     pandas-2.2.2               |   py39h313beb8_0        12.2 MB
#     pillow-10.3.0              |   py39h80987f9_0         710 KB
#     pyparsing-3.0.9            |   py39hca03da5_0         149 KB
#     scipy-1.13.1               |   py39hd336fd7_0        20.6 MB
#     seaborn-0.13.2             |   py39hca03da5_0         590 KB
#     unicodedata2-15.1.0        |   py39h80987f9_0         533 KB
#     zstd-1.5.5                 |       hd90d995_2         504 KB
#     ------------------------------------------------------------
#                                            Total:        51.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   bottleneck         pkgs/main/osx-arm64::bottleneck-1.3.7-py39hbda83bc_0
#   brotli             pkgs/main/osx-arm64::brotli-1.0.9-h80987f9_8
#   brotli-bin         pkgs/main/osx-arm64::brotli-bin-1.0.9-h80987f9_8
#   contourpy          pkgs/main/osx-arm64::contourpy-1.2.0-py39h48ca7d4_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/osx-arm64::fonttools-4.51.0-py39h80987f9_0
#   freetype           pkgs/main/osx-arm64::freetype-2.12.1-h1192e45_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9e-h80987f9_1
#   kiwisolver         pkgs/main/osx-arm64::kiwisolver-1.4.4-py39h313beb8_0
#   lcms2              pkgs/main/osx-arm64::lcms2-2.12-hba8e193_0
#   lerc               pkgs/main/osx-arm64::lerc-3.0-hc377ac9_0
#   libbrotlicommon    pkgs/main/osx-arm64::libbrotlicommon-1.0.9-h80987f9_8
#   libbrotlidec       pkgs/main/osx-arm64::libbrotlidec-1.0.9-h80987f9_8
#   libbrotlienc       pkgs/main/osx-arm64::libbrotlienc-1.0.9-h80987f9_8
#   libdeflate         pkgs/main/osx-arm64::libdeflate-1.17-h80987f9_1
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.21-h269037a_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.5.1-h313beb8_0
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.3.2-h80987f9_0
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-14.0.6-hc6e5704_0
#   lz4-c              pkgs/main/osx-arm64::lz4-c-1.9.4-h313beb8_1
#   matplotlib         pkgs/main/osx-arm64::matplotlib-3.8.4-py39hca03da5_0
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.8.4-py39h46d7db6_0
#   numexpr            pkgs/main/osx-arm64::numexpr-2.8.7-py39hecc3335_0
#   numpy              pkgs/main/osx-arm64::numpy-1.26.4-py39h3b2db8e_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.26.4-py39ha9811e2_0
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.4.0-h0ed58ac_2
#   pandas             pkgs/main/osx-arm64::pandas-2.2.2-py39h313beb8_0
#   pillow             pkgs/main/osx-arm64::pillow-10.3.0-py39h80987f9_0
#   pybind11-abi       pkgs/main/noarch::pybind11-abi-4-hd3eb1b0_1
#   pyparsing          pkgs/main/osx-arm64::pyparsing-3.0.9-py39hca03da5_0
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#   scipy              pkgs/main/osx-arm64::scipy-1.13.1-py39hd336fd7_0
#   seaborn            pkgs/main/osx-arm64::seaborn-0.13.2-py39hca03da5_0
#   unicodedata2       pkgs/main/osx-arm64::unicodedata2-15.1.0-py39h80987f9_0
#   zstd               pkgs/main/osx-arm64::zstd-1.5.5-hd90d995_2
#
#
#
# Downloading and Extracting Packages:
# scipy-1.13.1         | 20.6 MB   |                                       |   0%
# pandas-2.2.2         | 12.2 MB   |                                       |   0%
#
# matplotlib-base-3.8. | 6.7 MB    |                                       |   0%
#
#
# numpy-base-1.26.4    | 5.8 MB    |                                       |   0%
#
#
#
# fonttools-4.51.0     | 2.4 MB    |                                       |   0%
#
#
#
#
# pillow-10.3.0        | 710 KB    |                                       |   0%
#
#
#
#
#
# seaborn-0.13.2       | 590 KB    |                                       |   0%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    |                                       |   0%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# openjpeg-2.4.0       | 307 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 291 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 239 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 149 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.7        | 124 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 110 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 70 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 61 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 9 KB      |                                       |   0%
#
#
# scipy-1.13.1         | 20.6 MB   |                                       |   0%
#
# matplotlib-base-3.8. | 6.7 MB    |                                       |   0%
# pandas-2.2.2         | 12.2 MB   |                                       |   0%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | 2                                     |   1%
#
# matplotlib-base-3.8. | 6.7 MB    | #1                                    |   3%
# pandas-2.2.2         | 12.2 MB   | 6                                     |   2%
#
#
#
# scipy-1.13.1         | 20.6 MB   | 4                                     |   1%
#
#
# numpy-base-1.26.4    | 5.8 MB    | 7                                     |   2%
#
# scipy-1.13.1         | 20.6 MB   | 9                                     |   3%
# pandas-2.2.2         | 12.2 MB   | 9                                     |   3%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ####1                                 |  11%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #3                                    |   4%
# pandas-2.2.2         | 12.2 MB   | #2                                    |   3%
#
# scipy-1.13.1         | 20.6 MB   | #2                                    |   3%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #6                                    |   5%
# pandas-2.2.2         | 12.2 MB   | ##3                                   |   6%
#
# matplotlib-base-3.8. | 6.7 MB    | #####5                                |  15%
#
#
#
# scipy-1.13.1         | 20.6 MB   | #8                                    |   5%
# pandas-2.2.2         | 12.2 MB   | ###3                                  |   9%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ########1                             |  22%
#
#
# scipy-1.13.1         | 20.6 MB   | ##1                                   |   6%
# pandas-2.2.2         | 12.2 MB   | ###9                                  |  11%
#
# matplotlib-base-3.8. | 6.7 MB    | ######9                               |  19%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | #############                         |  35%
#
#
# scipy-1.13.1         | 20.6 MB   | ##7                                   |   7%
#
# matplotlib-base-3.8. | 6.7 MB    | ########6                             |  23%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ###############4                      |  42%
# pandas-2.2.2         | 12.2 MB   | ####4                                 |  12%
#
#
# scipy-1.13.1         | 20.6 MB   | ###1                                  |   9%
# scipy-1.13.1         | 20.6 MB   | ###5                                  |  10%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #####1                                |  14%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | #################9                    |  49%
#
# matplotlib-base-3.8. | 6.7 MB    | #########9                            |  27%
# pandas-2.2.2         | 12.2 MB   | #####3                                |  15%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ####################1                 |  55%
#
# matplotlib-base-3.8. | 6.7 MB    | ##########9                           |  30%
# scipy-1.13.1         | 20.6 MB   | ###9                                  |  11%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #####7                                |  16%
#
#
#
# scipy-1.13.1         | 20.6 MB   | #####1                                |  14%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #######2                              |  20%
# pandas-2.2.2         | 12.2 MB   | #######2                              |  20%
#
# matplotlib-base-3.8. | 6.7 MB    | #############4                        |  36%
# pandas-2.2.2         | 12.2 MB   | #######6                              |  21%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #######9                              |  22%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ############################2         |  76%
#
# scipy-1.13.1         | 20.6 MB   | #####6                                |  15%
# pandas-2.2.2         | 12.2 MB   | ########4                             |  23%
#
# scipy-1.13.1         | 20.6 MB   | ######8                               |  18%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #########4                            |  26%
# pandas-2.2.2         | 12.2 MB   | ##########3                           |  28%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ##################################1   |  92%
#
#
#
# scipy-1.13.1         | 20.6 MB   | #######4                              |  20%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##########2                           |  28%
# pandas-2.2.2         | 12.2 MB   | ###########2                          |  30%
#
# scipy-1.13.1         | 20.6 MB   | ########                              |  22%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##########9                           |  30%
# pandas-2.2.2         | 12.2 MB   | ###########9                          |  32%
#
#
#
#
# pillow-10.3.0        | 710 KB    | 8                                     |   2%
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ##################################### | 100%
#
# matplotlib-base-3.8. | 6.7 MB    | ####################7                 |  56%
# pandas-2.2.2         | 12.2 MB   | ############6                         |  34%
#
#
#
#
# pillow-10.3.0        | 710 KB    | ####1                                 |  11%
#
# scipy-1.13.1         | 20.6 MB   | ########5                             |  23%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###########5                          |  31%
#
#
#
#
# pillow-10.3.0        | 710 KB    | ####################                  |  54%
#
# matplotlib-base-3.8. | 6.7 MB    | ######################7               |  62%
#
#
# scipy-1.13.1         | 20.6 MB   | #########4                            |  25%
# pandas-2.2.2         | 12.2 MB   | #############6                        |  37%
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | #########9                            |  27%
# pandas-2.2.2         | 12.2 MB   | ##############1                       |  38%
#
# matplotlib-base-3.8. | 6.7 MB    | #######################6              |  64%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #############1                        |  36%
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ##########5                           |  29%
# pandas-2.2.2         | 12.2 MB   | ###############2                      |  41%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##############                        |  38%
#
# matplotlib-base-3.8. | 6.7 MB    | #########################             |  68%
#
#
#
#
# pillow-10.3.0        | 710 KB    | ##################################### | 100%
# scipy-1.13.1         | 20.6 MB   | ###########3                          |  31%
#
# matplotlib-base-3.8. | 6.7 MB    | ##########################4           |  72%
#
#
# scipy-1.13.1         | 20.6 MB   | ###########7                          |  32%
# pandas-2.2.2         | 12.2 MB   | ################7                     |  45%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###############6                      |  42%
#
# matplotlib-base-3.8. | 6.7 MB    | ###########################4          |  74%
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ############2                         |  33%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ################2                     |  44%
#
#
#
#
#
# seaborn-0.13.2       | 590 KB    | #########                             |  24%
# pandas-2.2.2         | 12.2 MB   | #################2                    |  47%
#
# matplotlib-base-3.8. | 6.7 MB    | ############################2         |  76%
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ############6                         |  34%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ################8                     |  46%
#
# matplotlib-base-3.8. | 6.7 MB    | #############################         |  78%
# pandas-2.2.2         | 12.2 MB   | #################8                    |  48%
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | #############                         |  35%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #################3                    |  47%
#
# matplotlib-base-3.8. | 6.7 MB    | #############################8        |  81%
# pandas-2.2.2         | 12.2 MB   | ##################2                   |  49%
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | #############4                        |  36%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #################8                    |  48%
# pandas-2.2.2         | 12.2 MB   | ##################7                   |  51%
#
# matplotlib-base-3.8. | 6.7 MB    | ##############################4       |  82%
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | #############7                        |  37%
#
# matplotlib-base-3.8. | 6.7 MB    | ###############################1      |  84%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##################3                   |  50%
# pandas-2.2.2         | 12.2 MB   | ###################1                  |  52%
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ##############4                       |  39%
#
# matplotlib-base-3.8. | 6.7 MB    | ################################1     |  87%
# pandas-2.2.2         | 12.2 MB   | ###################6                  |  53%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###################2                  |  52%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | #1                                    |   3%
# scipy-1.13.1         | 20.6 MB   | ##############8                       |  40%
#
# matplotlib-base-3.8. | 6.7 MB    | ################################8     |  89%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | #######7                              |  21%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###################8                  |  54%
# scipy-1.13.1         | 20.6 MB   | ###############2                      |  41%
#
# matplotlib-base-3.8. | 6.7 MB    | #################################5    |  91%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ####################3                 |  55%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ################6                     |  45%
# scipy-1.13.1         | 20.6 MB   | ###############6                      |  42%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | #######################3              |  63%
#
# matplotlib-base-3.8. | 6.7 MB    | ##################################2   |  93%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ####################8                 |  56%
# scipy-1.13.1         | 20.6 MB   | ###############9                      |  43%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ############################8         |  78%
#
# matplotlib-base-3.8. | 6.7 MB    | ##################################8   |  94%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #####################3                |  58%
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ################2                     |  44%
# pandas-2.2.2         | 12.2 MB   | #####################6                |  58%
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ##################################### | 100%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #####################7                |  59%
#
# matplotlib-base-3.8. | 6.7 MB    | ###################################4  |  96%
# scipy-1.13.1         | 20.6 MB   | ################5                     |  45%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    | #1                                    |   3%
# pandas-2.2.2         | 12.2 MB   | ######################1               |  60%
#
# scipy-1.13.1         | 20.6 MB   | ################7                     |  45%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ######################                |  60%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    | #######                               |  19%
# scipy-1.13.1         | 20.6 MB   | #################3                    |  47%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ######################8               |  62%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    | ############9                         |  35%
# scipy-1.13.1         | 20.6 MB   | #################8                    |  48%
#
#
#
#
#
#
#
#
# openjpeg-2.4.0       | 307 KB    | #9                                    |   5%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #######################4              |  63%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    | ######################3               |  60%
# scipy-1.13.1         | 20.6 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
# openjpeg-2.4.0       | 307 KB    | #################3                    |  47%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #######################9              |  65%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    | ##############################5       |  83%
# pandas-2.2.2         | 12.2 MB   | ########################3             |  66%
#
# matplotlib-base-3.8. | 6.7 MB    | ##################################### | 100%
#
# scipy-1.13.1         | 20.6 MB   | ##################5                   |  50%
#
#
#
#
#
#
#
#
# openjpeg-2.4.0       | 307 KB    | ##############################8       |  83%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ########################4             |  66%
#
#
#
#
#
#
#
# zstd-1.5.5           | 504 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# openjpeg-2.4.0       | 307 KB    | ##################################### | 100%
# scipy-1.13.1         | 20.6 MB   | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 291 KB    | ##                                    |   5%
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 239 KB    | ##4                                   |   7%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #########################             |  68%
# scipy-1.13.1         | 20.6 MB   | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 291 KB    | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 239 KB    | ###################8                  |  54%
#
#
# scipy-1.13.1         | 20.6 MB   | ###################7                  |  53%
# pandas-2.2.2         | 12.2 MB   | #########################8            |  70%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 291 KB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 239 KB    | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 239 KB    | ##################################### | 100%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##########################            |  71%
#
#
#
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ####################1                 |  54%
# pandas-2.2.2         | 12.2 MB   | ##########################3           |  71%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ####################5                 |  55%
# pandas-2.2.2         | 12.2 MB   | ##########################8           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 149 KB    | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ##################9                   |  51%
#
#
# scipy-1.13.1         | 20.6 MB   | ####################8                 |  56%
# pandas-2.2.2         | 12.2 MB   | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 149 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ##################################### | 100%
#
#
# scipy-1.13.1         | 20.6 MB   | #####################4                |  58%
# pandas-2.2.2         | 12.2 MB   | ###########################9          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.7        | 124 KB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 110 KB    | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.7        | 124 KB    | #################################3    |  90%
# scipy-1.13.1         | 20.6 MB   | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.7        | 124 KB    | ##################################### | 100%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ############################6         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 110 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 110 KB    | ##################################### | 100%
# scipy-1.13.1         | 20.6 MB   | ######################2               |  60%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 70 KB     | ########4                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 61 KB     | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 70 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ######################6               |  61%
# pandas-2.2.2         | 12.2 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 29 KB     | ####################5                 |  56%
#
#
# numpy-base-1.26.4    | 5.8 MB    | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 20 KB     | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | #######################4              |  63%
# pandas-2.2.2         | 12.2 MB   | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 18 KB     | #################################2    |  90%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | #######################9              |  65%
# pandas-2.2.2         | 12.2 MB   | ###############################       |  84%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.13.1         | 20.6 MB   | ########################4             |  66%
# pandas-2.2.2         | 12.2 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 9 KB      | ##################################### | 100%
#
#
# scipy-1.13.1         | 20.6 MB   | #########################             |  68%
# pandas-2.2.2         | 12.2 MB   | ################################3     |  88%
#
#
# scipy-1.13.1         | 20.6 MB   | #########################6            |  69%
# pandas-2.2.2         | 12.2 MB   | #################################     |  89%
#
#
# scipy-1.13.1         | 20.6 MB   | ##########################1           |  71%
# scipy-1.13.1         | 20.6 MB   | ##########################7           |  72%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ##################################5   |  93%
# scipy-1.13.1         | 20.6 MB   | ###########################2          |  74%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###################################2  |  95%
# scipy-1.13.1         | 20.6 MB   | ###########################7          |  75%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ###################################8  |  97%
# scipy-1.13.1         | 20.6 MB   | ############################3         |  77%
#
#
# numpy-base-1.26.4    | 5.8 MB    | ####################################4 |  99%
# scipy-1.13.1         | 20.6 MB   | ###################################8  |  97%
#
#
# scipy-1.13.1         | 20.6 MB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ### ... using pip

# %%
# Installiere die notwendigen Bibliotheken mit pip
import sys
# !{sys.executable} -m pip install numpy matplotlib pandas seaborn matplotlib scipy
